# %%
import pandas as pd

# %%
xls = pd.read_csv("Arsenal_PassesDetails_17_18.xls.csv",sep=';',skiprows=[0]) #use r before absolute file path 

xls
# Out:
#           Date          Heure              Comp                  Tour Jour  \
# 0   06/08/2017  14:00 (15:00)  Community Shield   FA Community Shield  Dim
# 1   11/08/2017  19:45 (20:45)    Premier League            Journ̩e 1  Ven
# 2   19/08/2017  17:30 (18:30)    Premier League            Journ̩e 2  Sam
# 3   27/08/2017  16:00 (17:00)    Premier League            Journ̩e 3  Dim
# 4   09/09/2017  15:00 (16:00)    Premier League            Journ̩e 4  Sam
# 5   14/09/2017  21:05 (22:05)         Europa Lg       Phase de groupe  Jeu
# 6   17/09/2017  13:30 (14:30)    Premier League            Journ̩e 5  Dim
# 7   20/09/2017  19:45 (20:45)           EFL Cup       Troisi̬me tour  Mer
# 8   25/09/2017  20:00 (21:00)    Premier League            Journ̩e 6  Lun
# 9   28/09/2017  20:00 (19:00)         Europa Lg       Phase de groupe  Jeu
# 10  01/10/2017  12:00 (13:00)    Premier League            Journ̩e 7  Dim
# ...
