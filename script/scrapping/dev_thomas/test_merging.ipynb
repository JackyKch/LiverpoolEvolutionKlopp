# %%
import pandas as pd

# %%
df_match = pd.read_csv('goalzz_archive_from_2012_v2.csv')

# %%
df_details = pd.read_csv('details_match_goalzz_100.csv')

# %%
pd.merge(df_match,df_details,left_on='date_match',right_on='Date',how='inner')
# Out:
#     date_match                contests                   home_team  \
# 0   2018-12-05  English Premier League                  Burnley FC
# 1   2018-12-08  English Premier League             AFC Bournemouth
# 2   2018-12-11   UEFA Champions League                   Liverpool
# 3   2018-12-16  English Premier League                   Liverpool
# 4   2018-12-21  English Premier League  Wolverhampton Wanderers FC
# ..         ...                     ...                         ...
# 71  2020-07-08  English Premier League      Brighton & Hove Albion
# 72  2020-07-11  English Premier League                   Liverpool
# 73  2020-07-15  English Premier League                  Arsenal FC
# 74  2020-07-22  English Premier League                   Liverpool
# 75  2020-07-26  English Premier League         Newcastle United FC
#
#     home_score  away_score          away_team liverpool_score  at_anfield  \
# 0            1           3          Liverpool               V       False
# ...

# %%
len(df_details)
# Out:
# 76

# %%
df_details.Date
# Out:
# 0     2018-12-05
# 1     2018-12-08
# 2     2018-12-11
# 3     2018-12-16
# 4     2018-12-21
#          ...
# 71    2020-07-08
# 72    2020-07-11
# 73    2020-07-15
# 74    2020-07-22
# 75    2020-07-26
# Name: Date, Length: 76, dtype: object

# %%
df_match.date_match
# Out:
# 0      2012-08-18
# 1      2012-08-23
# 2      2012-08-26
# 3      2012-08-30
# 4      2012-09-02
#           ...
# 470    2020-07-08
# 471    2020-07-11
# 472    2020-07-15
# 473    2020-07-22
# 474    2020-07-26
# Name: date_match, Length: 475, dtype: object
