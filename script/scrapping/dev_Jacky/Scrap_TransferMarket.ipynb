# %%
import requests
import pandas as pd

# %%
url = 'https://www.soccerbase.com/teams/team.sd?team_id=1563&teamTabs=transfers&season_id=153'

# %%
response = requests.get(url)

# %%
type(response)
# Out:
# requests.models.Response

# %%
html = response.content

# %%
response.status_code
# Out:
# 200

# %%
html
# Out:
# mp;season_id=153&amp;amp;teamTabs=transfers&quot; title=&quot;Go to Sheff Utd team page&quot;&gt;Sheff Utd&lt;/a&gt;&lt;/td&gt;&lt;td&gt;&amp;pound;23,500,000&lt;/td&gt;&lt;td&gt;02 Oct, 2020&lt;/td&gt;&lt;/tr&gt;&lt;tr&gt;&lt;td class=&quot;total&quot; colspan=&quot;4&quot;&gt; Total: &amp;pound;51,500,000 &lt;/td&gt;&lt;/tr&gt;&lt;/tbody&gt;&lt;/table&gt;&lt;div class=&quot;headlineBlock&quot;&gt;&lt;h3&gt;Players loaned in&lt;/h3&gt;&lt;/div&gt;&lt;table class=&quot;table&quot;&gt;&lt;colgroup&gt;&lt;col class=&quot;playerCol&quot; /&gt;&lt;col class=&quot;fromCol&quot; /&gt;&lt;col class=&quot;feeCol&quot; /&gt;&lt;col class=&quot;dateCol&quot; /&gt;&lt;/colgroup&gt;&lt;thead&gt;&lt;tr&gt;&lt;th class=&quot;first&quot;&gt;PLAYER&lt;/th&gt;&lt;th&gt;FROM&lt;/th&gt;&lt;th&gt;START&lt;/th&gt;&lt;th&gt;END&lt;/th&gt;&lt;/tr&gt;&lt;/thead&gt;&lt;tbody&gt;&lt;tr class=&quot;alt&quot;&gt;&lt;td class=&quot;first&quot; colspan=&quot;4&quot;&gt;None&lt;/td&gt;&lt;/tr&gt;&lt;/tbody&gt;&lt;
# ...

# %%
from bs4 import BeautifulSoup

# %%
soup = BeautifulSoup(html, 'html.parser')

# %%
type(soup)
# Out:
# bs4.BeautifulSoup

# %%
soup
# Out:
# /players/player.sd?player_id=102580&quot; title=&quot;Go to Rhian Brewster player profile page&quot;&gt;Rhian Brewster&lt;/a&gt;&lt;/td&gt;&lt;td&gt;&lt;a href=&quot;/teams/team.sd?team_id=2328&amp;amp;season_id=153&amp;amp;teamTabs=transfers&quot; title=&quot;Go to Sheff Utd team page&quot;&gt;Sheff Utd&lt;/a&gt;&lt;/td&gt;&lt;td&gt;£23,500,000&lt;/td&gt;&lt;td&gt;02 Oct, 2020&lt;/td&gt;&lt;/tr&gt;&lt;tr&gt;&lt;td class=&quot;total&quot; colspan=&quot;4&quot;&gt; Total: £51,500,000 &lt;/td&gt;&lt;/tr&gt;&lt;/tbody&gt;&lt;/table&gt;&lt;div class=&quot;headlineBlock&quot;&gt;&lt;h3&gt;Players loaned in&lt;/h3&gt;&lt;/div&gt;&lt;table class=&quot;table&quot;&gt;&lt;colgroup&gt;&lt;col class=&quot;playerCol&quot;/&gt;&lt;col class=&quot;fromCol&quot;/&gt;&lt;col class=&quot;feeCol&quot;/&gt;&lt;col class=&quot;dateCol&quot;/&gt;&lt;/colgroup&gt;&lt;thead&gt;&lt;tr&gt;&lt;th class=&quot;first&quot;&gt;PLAYER&lt;/th&gt;&lt;th&gt;FROM&lt;/th&gt;&lt;th&gt;START&lt;/th&gt;&lt;th&gt;END&lt;/t
# ...

# %%
req = soup.select('table tbody tr td ')[3]

# %%
req.contents
# Out:
# [&#39;10 Aug, 2020&#39;]

# %%
foot2Bis=[element.getText() for element in soup.select('table tbody tr td')]

# %%
id,equipe,prix,date=foot2Bis[0:12:4],foot2Bis[1:13:4],foot2Bis[2:14:4],foot2Bis[3:15:4]

# %%
id
# Out:
# [&#39;Kostas Tsimikas&#39;, &#39;Thiago&#39;, &#39;Diogo Jota&#39;]

# %%
df = pd.DataFrame({'NomJoueur':id,
                    'Equipe':equipe,
                    'Prix':prix,
                    'Date':date})

df
# Out:
#          NomJoueur      Equipe         Prix          Date
# 0  Kostas Tsimikas  Olympiakos  £11,700,000  10 Aug, 2020
# 1           Thiago    B Munich  £20,000,000  18 Sep, 2020
# 2       Diogo Jota      Wolves  £41,000,000  19 Sep, 2020
