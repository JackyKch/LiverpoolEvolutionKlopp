# %%
import requests

# %%
url = "https://www.lequipe.fr/Football/championnat-d-angleterre/page-classement-individuel/buteurs"

# %%
response = requests.get(url)

# %%
type(response)
# Out:
# requests.models.Response

# %%
html = response.content

# %%
response.status_code
# Out:
# 200

# %%
html
# Out:
#                   Paul Pogba\n                        &lt;/a&gt;&lt;/li&gt;&lt;li data-v-7eaa97f7=&quot;&quot;&gt;&lt;a data-v-7eaa97f7=&quot;&quot; href=&quot;/Football/FootballFicheJoueur28423.html&quot; class=&quot;Link Footer__link&quot; aria-label=&quot;/Football/FootballFicheJoueur28423.html&quot;&gt;\n                            Eden Hazard\n                        &lt;/a&gt;&lt;/li&gt;&lt;li data-v-7eaa97f7=&quot;&quot;&gt;&lt;a data-v-7eaa97f7=&quot;&quot; href=&quot;/Football/FootballFicheJoueur45572.html&quot; class=&quot;Link Footer__link&quot; aria-label=&quot;/Football/FootballFicheJoueur45572.html&quot;&gt;\n                            N\&#39;Golo Kant\xc3\xa9\n                        &lt;/a&gt;&lt;/li&gt;&lt;li data-v-7eaa97f7=&quot;&quot;&gt;&lt;a data-v-7eaa97f7=&quot;&quot; href=&quot;/Football/FootballFicheJoueur4116.html&quot; class=&quot;Link Footer__link&quot; aria-label=&quot;/Football/FootballFicheJoueur4116.html&quot;&gt;\n                            Didier 
# ...

# %%
from bs4 import BeautifulSoup

# %%
soup = BeautifulSoup(html,'html.parser')

# %%
type(soup)
# Out:
# bs4.BeautifulSoup

# %%
soup
# Out:
# -7eaa97f7=&quot;&quot; href=&quot;/Football/FootballFicheJoueur58221.html&quot;&gt;
#                             Kylian Mbappé
#                         &lt;/a&gt;&lt;/li&gt;&lt;li data-v-7eaa97f7=&quot;&quot;&gt;&lt;a aria-label=&quot;/Football/FootballFicheJoueur34803.html&quot; class=&quot;Link Footer__link&quot; data-v-7eaa97f7=&quot;&quot; href=&quot;/Football/FootballFicheJoueur34803.html&quot;&gt;
#                             Paul Pogba
#                         &lt;/a&gt;&lt;/li&gt;&lt;li data-v-7eaa97f7=&quot;&quot;&gt;&lt;a aria-label=&quot;/Football/FootballFicheJoueur28423.html&quot; class=&quot;Link Footer__link&quot; data-v-7eaa97f7=&quot;&quot; href=&quot;/Football/FootballFicheJoueur28423.html&quot;&gt;
#                             Eden Hazard
# ...

# %%
soup.select('a.Link.table__playerName')
# Out:
#                      &lt;div class=&quot;table__teamName table__link&quot;&gt;
#                                  Wolverhampton
#                              &lt;/div&gt;&lt;/a&gt;,
#  &lt;a aria-label=&quot;/Football/FootballFicheJoueur52897.html&quot; class=&quot;Link table__playerName table__link&quot; href=&quot;/Football/FootballFicheJoueur52897.html&quot;&gt;
#                              Helder Costa
#                              &lt;div class=&quot;table__teamName table__link&quot;&gt;
#                                  Leeds
#                              &lt;/div&gt;&lt;/a&gt;,
#  &lt;a aria-label=&quot;/Football/FootballFicheJoueur41405.html&quot; class=&quot;Link table__playerName table__link&quot; href=&quot;/Football/FootballFicheJoueur41405.html&quot;&gt;
#                              Mateusz Klich
#                              &lt;div class=&quot;table__teamName table__link&quot;&gt;
#                                  Leeds
# ...

# %%
soup.select ('tr td')[1].get_text()
# Out:
# &#39;\n                            Dominic Calvert-Lewin\n                            \n                                Everton\n                            &#39;

# %%
elements = soup.select ('td')

# %%
elements
# Out:
#                         3
#                          &lt;!-- --&gt;&lt;/td&gt;,
#  &lt;td class=&quot;table__col&quot;&gt;
#                          0.33
#                      &lt;/td&gt;,
#  &lt;td class=&quot;table__col table__col--rank&quot;&gt;
#                          -
#
#                      &lt;/td&gt;,
#  &lt;td class=&quot;table__col table__col--name&quot;&gt;&lt;a aria-label=&quot;/Football/FootballFicheJoueur41117.html&quot; class=&quot;Link table__playerName table__link&quot; href=&quot;/Football/FootballFicheJoueur41117.html&quot;&gt;
#                              Virgil Van Dijk
#                              &lt;div class=&quot;table__teamName table__link&quot;&gt;
#                                  Liverpool
#                              &lt;/div&gt;&lt;/a&gt;&lt;/td&gt;,
#  &lt;td class=&quot;table__col&quot;&gt;&lt;span class=&quot;table__sort table__col--sorted&quot;&gt;
#                              1&lt;/span&gt;&lt;/td&gt;,
# ...

# %%
text_data = [element.get_text() for element in elements]

# %%
text_data
# Out:
# &#39;,
#  &#39;\n                        1\n                    &#39;,
#  &#39;\n                        -\n                        \n                    &#39;,
#  &#39;\n                            Gabriel Magalhaes\n                            \n                                Arsenal\n                            &#39;,
#  &#39;\n                            1&#39;,
#  &#39;\n                        2\n                        &#39;,
#  &#39;\n                        0.5\n                    &#39;,
#  &#39;\n                        -\n                        \n                    &#39;,
#  &#39;\n                            Jack Grealish\n                            \n                                Aston Villa\n                            &#39;,
#  &#39;\n                            1&#39;,
#  &#39;\n                        2\n                        &#39;,
#  &#39;\n                        0.5\n                    &#39;,
# ...

# %%
nom = text_data[::2]

# %%
nom
# Out:
# [&#39;\n                        3\n                        &#39;,
#  &#39;\n                        3\n                        \n                    &#39;,
#  &#39;\n                            4&#39;,
#  &#39;\n                        1.33\n                    &#39;,
#  &#39;\n                            Neal Maupay\n                            \n                                Brighton\n                            &#39;,
#  &#39;\n                        4\n                        &#39;,
#  &#39;\n                        -\n                        \n                    &#39;,
#  &#39;\n                            4&#39;,
#  &#39;\n                        1\n                    &#39;,
#  &#39;\n                            Alexandre Lacazette\n                            \n                                Arsenal\n                            &#39;,
#  &#39;\n                        3\n                        &#39;,
# ...
