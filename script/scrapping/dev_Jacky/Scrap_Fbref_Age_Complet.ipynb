# %%
from selenium import webdriver

# %%
import pandas as pd

# %%
options = webdriver.ChromeOptions()

# %%
options.add_argument("--incognito")

# %%
driver = webdriver.Chrome("./chromedriver.exe", options=options)

# %% [markdown]
# ## Récupérer le nom des joueurs et leur âge par saison

# %%
driver.get("https://fbref.com/en/squads/822bd0ba/2012-2013/Liverpool-Stats")
element = driver.find_elements_by_xpath('//div[@id = "div_stats_standard_602"] //tbody //th[@data-append-csv]')
lst_players2012_2013 = [x.text for x in element]
element = driver.find_elements_by_xpath('//div[@id = "div_stats_standard_602"] //tbody //td[@data-stat = "age"]')
lst_age2012_2013 = [x.text for x in element]

# %%
driver.get("https://fbref.com/en/squads/822bd0ba/2013-2014/Liverpool-Stats")
element = driver.find_elements_by_xpath('//div[@id = "div_stats_standard_669"] //tbody //th[@data-append-csv]')
lst_players2013_2014 = [x.text for x in element]
element = driver.find_elements_by_xpath('//div[@id = "div_stats_standard_669"] //tbody //td[@data-stat = "age"]')
lst_age2013_2014 = [x.text for x in element]

# %%
driver.get("https://fbref.com/en/squads/822bd0ba/2014-2015/Liverpool-Stats")
element = driver.find_elements_by_xpath('//div[@id = "div_stats_standard_733"] //tbody //th[@data-append-csv]')
lst_players2014_2015 = [x.text for x in element]
element = driver.find_elements_by_xpath('//div[@id = "div_stats_standard_733"] //tbody //td[@data-stat = "age"]')
lst_age2014_2015 = [x.text for x in element]

# %%
driver.get("https://fbref.com/en/squads/822bd0ba/2015-2016/Liverpool-Stats")
element = driver.find_elements_by_xpath('//div[@id = "div_stats_standard_1467"] //tbody //th[@data-append-csv]')
lst_players2015_2016 = [x.text for x in element]
element = driver.find_elements_by_xpath('//div[@id = "div_stats_standard_1467"] //tbody //td[@data-stat = "age"]')
lst_age2015_2016 = [x.text for x in element]

# %%
driver.get("https://fbref.com/en/squads/822bd0ba/2016-2017/Liverpool-Stats")
element = driver.find_elements_by_xpath('//div[@id = "div_stats_standard_1526"] //tbody //th[@data-append-csv]')
lst_players2016_2017 = [x.text for x in element]
element = driver.find_elements_by_xpath('//div[@id = "div_stats_standard_1526"] //tbody //td[@data-stat = "age"]')
lst_age2016_2017 = [x.text for x in element]

# %%
driver.get("https://fbref.com/en/squads/822bd0ba/2017-2018/Liverpool-Stats")
element = driver.find_elements_by_xpath('//div[@id = "div_stats_standard_1631"] //tbody //th[@data-append-csv]')
lst_players2017_2018 = [x.text for x in element]
element = driver.find_elements_by_xpath('//div[@id = "div_stats_standard_1631"] //tbody //td[@data-stat = "age"]')
lst_age2017_2018 = [x.text for x in element]

# %%
driver.get("https://fbref.com/en/squads/822bd0ba/2018-2019/Liverpool-Stats")
element = driver.find_elements_by_xpath('//div[@id = "div_stats_standard_1889"] //tbody //th[@data-append-csv]')
lst_players2018_2019 = [x.text for x in element]
element = driver.find_elements_by_xpath('//div[@id = "div_stats_standard_1889"] //tbody //td[@data-stat = "age"]')
lst_age2018_2019 = [x.text for x in element]

# %%
driver.get("https://fbref.com/en/squads/822bd0ba/2019-2020/Liverpool-Stats")
element = driver.find_elements_by_xpath('//div[@id = "div_stats_standard_3232"] //tbody //th[@data-append-csv]')
lst_players2019_2020 = [x.text for x in element]
element = driver.find_elements_by_xpath('//div[@id = "div_stats_standard_3232"] //tbody //td[@data-stat = "age"]')
lst_age2019_2020 = [x.text for x in element]

# %%
test = {"salah":{"2012/2013" : 26, "2013/2014" : 27},
        "mane" :{"2012/2013" : 28}
}

# %%
pd.DataFrame.from_dict(test).transpose()
# Out:
#        2012/2013  2013/2014
# salah       26.0       27.0
# mane        28.0        NaN

# %%
test2 = {"2012/2013" : {"Salah" : 25, "Gerrard" : 35},
         "2013/2014" : {"Salah" : 26, "Mané" : 28},
         "2014/2015" : {"Mané" : 29, "Firmino" : 27}
         }

# %%
pd.DataFrame.from_dict(test2)
# Out:
#          2012/2013  2013/2014  2014/2015
# Salah         25.0       26.0        NaN
# Gerrard       35.0        NaN        NaN
# Mané           NaN       28.0       29.0
# Firmino        NaN        NaN       27.0

# %% [markdown]
# ## On crée des dictionnaires de dictionnaires pour stocker toutes les données

# %%
dicttest3 = {}

# %%
dicttest3['2012/2013'] = {}

# %%
for i in lst_players2012_2013 :
    for j in range(len(lst_age2012_2013)) :
        dicttest3["2012/2013"][lst_players2012_2013[j]] = lst_age2012_2013[j]

# %%
df2 = pd.DataFrame.from_dict(dicttest3)

# %%
df2
# Out:
#                   2012/2013
# Andre Wisdom             19
# Andy Carroll             23
# Brad Jones               30
# Conor Coady              19
# Daniel Agger             27
# Daniel Sturridge         22
# Fabio Borini             21
# Glen Johnson             27
# Jamie Carragher          34
# Joe Allen                22
# Joe Cole                 30
# Jonjo Shelvey            20
# Jordan Henderson         22
# Jordon Ibe               16
# José Enrique             26
# Lucas Leiva              25
# Luis Suárez              25
# Martin Kelly             22
# Martin Škrtel            27
# Nuri Şahin               23
# Oussama Assaidi          23
# Pepe Reina               29
# Philippe Coutinho        20
# Raheem Sterling          17
# Sebastián Coates         21
# Steven Gerrard           32
# Stewart Downing          28
# Suso                     18

# %%
dicttest3['2013/2014'] = {}
for i in lst_players2013_2014 :
    for j in range(len(lst_age2013_2014)) :
        dicttest3["2013/2014"][lst_players2013_2014[j]] = lst_age2013_2014[j]

# %%
df3 = pd.DataFrame.from_dict(dicttest3)

# %%
dicttest3['2014/2015'] = {}
for i in lst_players2014_2015 :
    for j in range(len(lst_age2014_2015)) :
        dicttest3["2014/2015"][lst_players2014_2015[j]] = lst_age2014_2015[j]

# %%
df4 = pd.DataFrame.from_dict(dicttest3)

# %%
dicttest3['2015/2016'] = {}
for i in lst_players2015_2016 :
    for j in range(len(lst_age2015_2016)) :
        dicttest3["2015/2016"][lst_players2015_2016[j]] = lst_age2015_2016[j]

# %%
df5 = pd.DataFrame.from_dict(dicttest3)

# %%
dicttest3['2016/2017'] = {}
for j in range(len(lst_age2016_2017)) :
    dicttest3["2016/2017"][lst_players2016_2017[j]] = lst_age2016_2017[j]

# %%
df6 = pd.DataFrame.from_dict(dicttest3)

# %%
dicttest3['2017/2018'] = {}
for j in range(len(lst_age2017_2018)) :
    dicttest3["2017/2018"][lst_players2017_2018[j]] = lst_age2017_2018[j]

# %%
df7 = pd.DataFrame.from_dict(dicttest3)

# %%
dicttest3['2018/2019'] = {}
for j in range(len(lst_age2018_2019)) :
    dicttest3["2018/2019"][lst_players2018_2019[j]] = lst_age2018_2019[j]

# %%
df8 = pd.DataFrame.from_dict(dicttest3)

# %%
dicttest3['2019/2020'] = {}
for j in range(len(lst_age2019_2020)) :
    dicttest3["2019/2020"][lst_players2019_2020[j]] = lst_age2019_2020[j]

# %%
df9 = pd.DataFrame.from_dict(dicttest3)

# %%
pd.set_option('display.max_rows', None)

# %%
df9
# Out:
#                         2012/2013 2013/2014 2014/2015 2015/2016 2016/2017  \
# Glen Johnson                   27        28        29       NaN       NaN
# Steven Gerrard                 32        33        34       NaN       NaN
# Daniel Agger                   27        28       NaN       NaN       NaN
# Luis Suárez                    25        26       NaN       NaN       NaN
# Pepe Reina                     29       NaN       NaN       NaN       NaN
# José Enrique                   26        27        28       NaN       NaN
# Stewart Downing                28       NaN       NaN       NaN       NaN
# Lucas Leiva                    25        26        27        28        29
# Martin Škrtel                  27        28        29        30       NaN
# Joe Allen                      22        23        24        25       NaN
# Raheem Sterling                17        18        19       NaN       NaN
# Jordan Henderson               22        23        24        25        26
# ...

# %%
driver.close()

# %%
df9.to_csv(r'C:\Users\jacky\Downloads\Work\ESILV\Projets\Liverpool\Test_Dev\age.csv', header = True, index = True)
