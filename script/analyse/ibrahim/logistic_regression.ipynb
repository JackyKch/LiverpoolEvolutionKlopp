# %%
v

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from numpy import mean,inf,arange
from numpy import std,var
from pandas import read_csv
from matplotlib import pyplot as plt
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import RepeatedStratifiedKFold,cross_val_score,GridSearchCV,train_test_split
from sklearn.metrics import plot_confusion_matrix,accuracy_score,classification_report

# %%
scaler = StandardScaler()

# %%
df = pd.read_csv('../../../data/dataset.csv')

# %%
len(df)
# Out:
# 346

# %%
def get_new_target(col):
    return 1 if col == 'V' else 0

# %%
df['new_target'] = df['liverpool_result_ft'].apply(get_new_target)

# %%
x = df.drop(columns=['liverpool_result_ft','new_target'])

# %%
y = df['liverpool_result_ft']

# %%
y_new=df['new_target']

# %%
x_scaled = pd.DataFrame(scaler.fit_transform(x), columns=x.columns)

# %%
def evaluate_model(X, y, model):
	# define evaluation procedure
	cv = RepeatedStratifiedKFold(n_splits=5, n_repeats=3, random_state=1)
	# evaluate model
	scores = cross_val_score(model, X, y, scoring='accuracy', cv=cv, n_jobs=-1)
	return scores

# %%
model = LogisticRegression()

# %%
part = []
mean_acc = []
for i in np.linspace(0.25,0.7,num=20):
    i=round(i,3)
    part.append(1-i)
    x_train, x_test, y_train, y_test = train_test_split(x_scaled,y_new,test_size = i)
    acc = evaluate_model(x_train,y_train,model)
    mean_acc.append(np.mean(acc))

# %%
part[8:]
# Out:
# [0.5609999999999999,
#  0.5369999999999999,
#  0.513,
#  0.489,
#  0.46599999999999997,
#  0.44199999999999995,
#  0.41800000000000004,
#  0.395,
#  0.371,
#  0.347,
#  0.32399999999999995,
#  0.30000000000000004]

# %%
sns.set_context("poster")
f, axs = plt.subplots(1,1,figsize=(10,10))
pl = sns.lineplot(x=part[:-3],y=mean_acc[:-3])
pl.set(xlabel= "Pourcentage échantillon d'entrainement",ylabel="Accuracy")
plt.savefig('lr_split_pourcentage.jpg')

# %%
nb_list = [int(i * len(x_scaled)) for i in part]

# %%
sns.set_context("poster")
f, axs = plt.subplots(1,1,figsize=(10,10))
pl = sns.lineplot(x=nb_list[:-3],y=mean_acc[:-3])
pl.set(xlabel= "Taille échantillon d'entrainement",ylabel="Accuracy")
plt.savefig('lr_split_nombre.jpg')

# %% [markdown]
# # Binary Classification

# %%
x_train, x_test, y_train, y_test = train_test_split(x_scaled,y_new,test_size = 0.3)

# %%
model = LogisticRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
plot_confusion_matrix(model,x_test,y_test,cmap='Reds')
plt.savefig('lr_confusion_matrix_binaire.jpg')

# %%
accuracy_score(y_test,model.predict(x_test))
# Out:
# 0.6634615384615384

# %%
print(classification_report(y_test,model.predict(x_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.62      0.47      0.53        43
#            1       0.68      0.80      0.74        61
#
#     accuracy                           0.66       104
#    macro avg       0.65      0.63      0.64       104
# weighted avg       0.66      0.66      0.65       104

# %% [markdown]
# # Multi Classification

# %%
x_train, x_test, y_train, y_test = train_test_split(x_scaled,y,test_size = 0.3)

# %%
model = LogisticRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
plot_confusion_matrix(model,x_test,y_test)
plt.savefig('lr_confusion_matrix_multi.jpg')

# %%
accuracy_score(y_test,model.predict(x_test))
# Out:
# 0.6346153846153846

# %%
print(classification_report(y_test,model.predict(x_test)))
# Out:
#               precision    recall  f1-score   support
#
#            D       0.75      0.39      0.51        23
#            N       0.38      0.27      0.32        22
#            V       0.67      0.86      0.76        59
#
#     accuracy                           0.63       104
#    macro avg       0.60      0.51      0.53       104
# weighted avg       0.63      0.63      0.61       104

# %%
df_multi = pd.DataFrame(classification_report(y_test,model.predict(x_test)))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-76-60dd92336bd2> in <module>
# ----> 1 df_multi = pd.DataFrame(classification_report(y_test,model.predict(x_test)))
#
# c:\users\ibrah\appdata\local\programs\python\python38\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     527         else:
#     528             if index is None or columns is None:
# --> 529                 raise ValueError("DataFrame constructor not properly called!")
#     530
#     531             if not dtype:
#
# ValueError: DataFrame constructor not properly called!

# %%
# define grid
grid = dict()
grid['penalty'] =  ['l1', 'l2']
grid['C'] = np.logspace(-4, 4, 20)
# define model evaluation method
cv = RepeatedStratifiedKFold(n_splits=5, n_repeats=3, random_state=1)
# define search
search = GridSearchCV(model, grid, scoring='accuracy', cv=cv, n_jobs=-1)

# %%
search.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=RepeatedStratifiedKFold(n_repeats=3, n_splits=5, random_state=1),
#              estimator=LogisticRegression(), n_jobs=-1,
#              param_grid={'C': array([1.00000000e-04, 2.63665090e-04, 6.95192796e-04, 1.83298071e-03,
#        4.83293024e-03, 1.27427499e-02, 3.35981829e-02, 8.85866790e-02,
#        2.33572147e-01, 6.15848211e-01, 1.62377674e+00, 4.28133240e+00,
#        1.12883789e+01, 2.97635144e+01, 7.84759970e+01, 2.06913808e+02,
#        5.45559478e+02, 1.43844989e+03, 3.79269019e+03, 1.00000000e+04]),
#                          'penalty': ['l1', 'l2']},
#              scoring='accuracy')

# %%
res =pd.DataFrame(search.cv_results_).sort_values('rank_test_score')

# %%
res
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time      param_C  \
# 13       0.015802      0.001794         0.003731        0.000572    0.0335982
# 17       0.018269      0.001845         0.003932        0.000440     0.233572
# 11       0.017310      0.003508         0.003838        0.000343    0.0127427
# 19       0.020998      0.002638         0.003934        0.000444     0.615848
# 15       0.017132      0.002060         0.004001        0.001155    0.0885867
# 21       0.023135      0.003592         0.003733        0.000443      1.62378
# 23       0.022924      0.003111         0.003733        0.000443      4.28133
# 27       0.027713      0.006821         0.004599        0.001201      29.7635
# 25       0.024860      0.004568         0.004056        0.000576      11.2884
# 37       0.026601      0.007207         0.005201        0.001869      3792.69
# 35       0.029736      0.008817         0.004399        0.001541      1438.45
# 33       0.026459      0.004609         0.004198        0.000835      545.559
# 31       0.026059      0.004995         0.004003        0.000518      206.914
# 29       0.028591      0.004990         0.005777        0.003874       78.476
# 39       0.024195      0.006010         0.003732        0.001655        10000
# 1        0.024200      0.005691         0.005796        0.002949       0.0001
# 3        0.018331      0.003364         0.004202        0.001722  0.000263665
# 9        0.016007      0.001310         0.004046        0.001002   0.00483293
# 7        0.017645      0.002268         0.004314        0.001076   0.00183298
# 5        0.017865      0.003014         0.007268        0.009110  0.000695193
# 12       0.001391      0.000486         0.000000        0.000000    0.0335982
# 36       0.001465      0.001021         0.000000        0.000000      3792.69
# 2        0.001868      0.001454         0.000000        0.000000  0.000263665
# 34       0.001531      0.000617         0.000000        0.000000      1438.45
# 32       0.001337      0.000470         0.000000        0.000000      545.559
# 4        0.001399      0.000486         0.000000        0.000000  0.000695193
# 30       0.001470      0.000617         0.000000        0.000000      206.914
# 28       0.001514      0.000637         0.000000        0.000000       78.476
# 6        0.001403      0.000490         0.000000        0.000000   0.00183298
# 26       0.001335      0.000472         0.000000        0.000000      29.7635
# 24       0.001402      0.000488         0.000000        0.000000      11.2884
# 8        0.001265      0.000445         0.000000        0.000000   0.00483293
# 22       0.001268      0.000441         0.000000        0.000000      4.28133
# 20       0.001267      0.000439         0.000000        0.000000      1.62378
# 38       0.001395      0.000489         0.000000        0.000000        10000
# 18       0.001234      0.000403         0.000000        0.000000     0.615848
# 10       0.001511      0.000796         0.000000        0.000000    0.0127427
# 16       0.001401      0.000489         0.000000        0.000000     0.233572
# 14       0.001864      0.001257         0.000000        0.000000    0.0885867
# 0        0.001739      0.000443         0.000000        0.000000       0.0001
#
#    param_penalty                                          params  \
# 13            l2     {'C': 0.03359818286283781, 'penalty': 'l2'}
# 17            l2     {'C': 0.23357214690901212, 'penalty': 'l2'}
# 11            l2    {'C': 0.012742749857031334, 'penalty': 'l2'}
# 19            l2       {'C': 0.615848211066026, 'penalty': 'l2'}
# 15            l2     {'C': 0.08858667904100823, 'penalty': 'l2'}
# 21            l2       {'C': 1.623776739188721, 'penalty': 'l2'}
# 23            l2       {'C': 4.281332398719396, 'penalty': 'l2'}
# 27            l2      {'C': 29.763514416313132, 'penalty': 'l2'}
# 25            l2      {'C': 11.288378916846883, 'penalty': 'l2'}
# 37            l2       {'C': 3792.690190732246, 'penalty': 'l2'}
# 35            l2        {'C': 1438.44988828766, 'penalty': 'l2'}
# 33            l2       {'C': 545.5594781168514, 'penalty': 'l2'}
# 31            l2        {'C': 206.913808111479, 'penalty': 'l2'}
# 29            l2       {'C': 78.47599703514607, 'penalty': 'l2'}
# 39            l2                 {'C': 10000.0, 'penalty': 'l2'}
# 1             l2                  {'C': 0.0001, 'penalty': 'l2'}
# 3             l2  {'C': 0.00026366508987303583, 'penalty': 'l2'}
# 9             l2    {'C': 0.004832930238571752, 'penalty': 'l2'}
# 7             l2   {'C': 0.0018329807108324356, 'penalty': 'l2'}
# 5             l2   {'C': 0.0006951927961775605, 'penalty': 'l2'}
# 12            l1     {'C': 0.03359818286283781, 'penalty': 'l1'}
# 36            l1       {'C': 3792.690190732246, 'penalty': 'l1'}
# 2             l1  {'C': 0.00026366508987303583, 'penalty': 'l1'}
# 34            l1        {'C': 1438.44988828766, 'penalty': 'l1'}
# 32            l1       {'C': 545.5594781168514, 'penalty': 'l1'}
# 4             l1   {'C': 0.0006951927961775605, 'penalty': 'l1'}
# 30            l1        {'C': 206.913808111479, 'penalty': 'l1'}
# 28            l1       {'C': 78.47599703514607, 'penalty': 'l1'}
# 6             l1   {'C': 0.0018329807108324356, 'penalty': 'l1'}
# 26            l1      {'C': 29.763514416313132, 'penalty': 'l1'}
# 24            l1      {'C': 11.288378916846883, 'penalty': 'l1'}
# 8             l1    {'C': 0.004832930238571752, 'penalty': 'l1'}
# 22            l1       {'C': 4.281332398719396, 'penalty': 'l1'}
# 20            l1       {'C': 1.623776739188721, 'penalty': 'l1'}
# 38            l1                 {'C': 10000.0, 'penalty': 'l1'}
# 18            l1       {'C': 0.615848211066026, 'penalty': 'l1'}
# 10            l1    {'C': 0.012742749857031334, 'penalty': 'l1'}
# 16            l1     {'C': 0.23357214690901212, 'penalty': 'l1'}
# 14            l1     {'C': 0.08858667904100823, 'penalty': 'l1'}
# 0             l1                  {'C': 0.0001, 'penalty': 'l1'}
#
#     split0_test_score  split1_test_score  split2_test_score  ...  \
# 13           0.523810           0.690476           0.585366  ...
# 17           0.547619           0.738095           0.609756  ...
# 11           0.595238           0.642857           0.560976  ...
# 19           0.571429           0.738095           0.585366  ...
# 15           0.547619           0.666667           0.585366  ...
# 21           0.595238           0.738095           0.536585  ...
# 23           0.595238           0.738095           0.536585  ...
# 27           0.595238           0.761905           0.536585  ...
# 25           0.595238           0.761905           0.536585  ...
# 37           0.595238           0.761905           0.536585  ...
# 35           0.595238           0.761905           0.536585  ...
# 33           0.595238           0.761905           0.536585  ...
# 31           0.595238           0.761905           0.536585  ...
# 29           0.595238           0.761905           0.536585  ...
# 39           0.595238           0.761905           0.536585  ...
# 1            0.571429           0.571429           0.585366  ...
# 3            0.571429           0.571429           0.585366  ...
# 9            0.571429           0.571429           0.585366  ...
# 7            0.571429           0.571429           0.585366  ...
# 5            0.571429           0.571429           0.585366  ...
# 12                NaN                NaN                NaN  ...
# 36                NaN                NaN                NaN  ...
# 2                 NaN                NaN                NaN  ...
# 34                NaN                NaN                NaN  ...
# 32                NaN                NaN                NaN  ...
# 4                 NaN                NaN                NaN  ...
# 30                NaN                NaN                NaN  ...
# 28                NaN                NaN                NaN  ...
# 6                 NaN                NaN                NaN  ...
# 26                NaN                NaN                NaN  ...
# 24                NaN                NaN                NaN  ...
# 8                 NaN                NaN                NaN  ...
# 22                NaN                NaN                NaN  ...
# 20                NaN                NaN                NaN  ...
# 38                NaN                NaN                NaN  ...
# 18                NaN                NaN                NaN  ...
# 10                NaN                NaN                NaN  ...
# 16                NaN                NaN                NaN  ...
# 14                NaN                NaN                NaN  ...
# 0                 NaN                NaN                NaN  ...
#
#     split8_test_score  split9_test_score  split10_test_score  \
# 13           0.707317           0.658537            0.642857
# 17           0.634146           0.634146            0.619048
# 11           0.658537           0.634146            0.619048
# 19           0.634146           0.634146            0.619048
# 15           0.658537           0.634146            0.642857
# 21           0.634146           0.658537            0.642857
# 23           0.634146           0.658537            0.642857
# 27           0.634146           0.658537            0.619048
# 25           0.634146           0.658537            0.619048
# 37           0.609756           0.658537            0.619048
# 35           0.609756           0.658537            0.619048
# 33           0.609756           0.658537            0.619048
# 31           0.609756           0.658537            0.619048
# 29           0.609756           0.658537            0.619048
# 39           0.609756           0.658537            0.619048
# 1            0.585366           0.585366            0.571429
# 3            0.585366           0.585366            0.571429
# 9            0.585366           0.585366            0.571429
# 7            0.585366           0.585366            0.571429
# 5            0.585366           0.585366            0.571429
# 12                NaN                NaN                 NaN
# 36                NaN                NaN                 NaN
# 2                 NaN                NaN                 NaN
# 34                NaN                NaN                 NaN
# 32                NaN                NaN                 NaN
# 4                 NaN                NaN                 NaN
# 30                NaN                NaN                 NaN
# 28                NaN                NaN                 NaN
# 6                 NaN                NaN                 NaN
# 26                NaN                NaN                 NaN
# 24                NaN                NaN                 NaN
# 8                 NaN                NaN                 NaN
# 22                NaN                NaN                 NaN
# 20                NaN                NaN                 NaN
# 38                NaN                NaN                 NaN
# 18                NaN                NaN                 NaN
# 10                NaN                NaN                 NaN
# 16                NaN                NaN                 NaN
# 14                NaN                NaN                 NaN
# 0                 NaN                NaN                 NaN
#
#     split11_test_score  split12_test_score  split13_test_score  \
# 13            0.571429            0.658537            0.609756
# 17            0.619048            0.609756            0.585366
# 11            0.571429            0.634146            0.609756
# 19            0.595238            0.658537            0.585366
# 15            0.595238            0.609756            0.585366
# 21            0.595238            0.658537            0.536585
# 23            0.595238            0.658537            0.536585
# 27            0.595238            0.658537            0.536585
# 25            0.595238            0.658537            0.536585
# 37            0.595238            0.658537            0.536585
# 35            0.595238            0.658537            0.536585
# 33            0.595238            0.658537            0.536585
# 31            0.595238            0.658537            0.536585
# 29            0.595238            0.658537            0.536585
# 39            0.595238            0.658537            0.536585
# 1             0.571429            0.585366            0.585366
# 3             0.571429            0.585366            0.585366
# 9             0.571429            0.585366            0.585366
# 7             0.571429            0.585366            0.585366
# 5             0.571429            0.585366            0.585366
# 12                 NaN                 NaN                 NaN
# 36                 NaN                 NaN                 NaN
# 2                  NaN                 NaN                 NaN
# 34                 NaN                 NaN                 NaN
# 32                 NaN                 NaN                 NaN
# 4                  NaN                 NaN                 NaN
# 30                 NaN                 NaN                 NaN
# 28                 NaN                 NaN                 NaN
# 6                  NaN                 NaN                 NaN
# 26                 NaN                 NaN                 NaN
# 24                 NaN                 NaN                 NaN
# 8                  NaN                 NaN                 NaN
# 22                 NaN                 NaN                 NaN
# 20                 NaN                 NaN                 NaN
# 38                 NaN                 NaN                 NaN
# 18                 NaN                 NaN                 NaN
# 10                 NaN                 NaN                 NaN
# 16                 NaN                 NaN                 NaN
# 14                 NaN                 NaN                 NaN
# 0                  NaN                 NaN                 NaN
#
#     split14_test_score  mean_test_score  std_test_score  rank_test_score
# 13            0.634146         0.618622        0.058241                1
# 17            0.609756         0.610298        0.057681                2
# 11            0.585366         0.608788        0.030478                3
# 19            0.609756         0.607162        0.060162                4
# 15            0.609756         0.607162        0.049744                4
# 21            0.609756         0.603755        0.058647                6
# 23            0.609756         0.597329        0.066980                7
# 27            0.609756         0.595703        0.071959                8
# 25            0.609756         0.595703        0.071959                8
# 37            0.609756         0.592451        0.073978               10
# 35            0.609756         0.592451        0.073978               10
# 33            0.609756         0.592451        0.073978               10
# 31            0.609756         0.592451        0.073978               10
# 29            0.609756         0.592451        0.073978               10
# 39            0.609756         0.592451        0.073978               10
# 1             0.585366         0.579791        0.006828               16
# 3             0.585366         0.579791        0.006828               16
# 9             0.585366         0.579791        0.006828               16
# 7             0.585366         0.579791        0.006828               16
# 5             0.585366         0.579791        0.006828               16
# 12                 NaN              NaN             NaN               21
# 36                 NaN              NaN             NaN               22
# 2                  NaN              NaN             NaN               23
# 34                 NaN              NaN             NaN               24
# 32                 NaN              NaN             NaN               25
# 4                  NaN              NaN             NaN               26
# 30                 NaN              NaN             NaN               27
# 28                 NaN              NaN             NaN               28
# 6                  NaN              NaN             NaN               29
# 26                 NaN              NaN             NaN               30
# 24                 NaN              NaN             NaN               31
# 8                  NaN              NaN             NaN               32
# 22                 NaN              NaN             NaN               33
# 20                 NaN              NaN             NaN               34
# 38                 NaN              NaN             NaN               35
# 18                 NaN              NaN             NaN               36
# 10                 NaN              NaN             NaN               37
# 16                 NaN              NaN             NaN               38
# 14                 NaN              NaN             NaN               39
# 0                  NaN              NaN             NaN               40
#
# [40 rows x 25 columns]

# %%
classification_report(y_test,model.predict(x_test))
# Out:
# '              precision    recall  f1-score   support\n\n           D       0.42      0.40      0.41        25\n           N       0.25      0.13      0.17        31\n           V       0.69      0.82      0.75        83\n\n    accuracy                           0.59       139\n   macro avg       0.45      0.45      0.44       139\nweighted avg       0.54      0.59      0.56       139\n'
