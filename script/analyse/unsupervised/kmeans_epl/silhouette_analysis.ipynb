# %% [markdown]
# ## Imports

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_samples, silhouette_score

import matplotlib.pyplot as plt
import matplotlib.cm as cm
import numpy as np
import pandas as pd

# %%
def silhouette(filename):

  data = pd.read_csv(filename)
  range_n_clusters = [2, 3, 4, 5, 6, 7, 8, 9, 10]

  for n_clusters in range_n_clusters:
    plt.figure()

    # The silhouette coefficient can range from -1, 1
    plt.xlim([-1, 1])

    # The (n_clusters+1)*10 is for inserting blank space between silhouette
    # plots of individual clusters, to demarcate them clearly.
    
    plt.ylim([0, len(data) + (n_clusters + 1) * 10])

    # Initialize the clusterer with n_clusters value and a random generator
    # seed of 10 for reproducibility.
    clusterer = KMeans(n_clusters=n_clusters, random_state=10)
    cluster_labels = clusterer.fit_predict(data)

    # The silhouette_score gives the average value for all the samples.
    # This gives a perspective into the density and separation of the formed
    # clusters

    silhouette_avg = silhouette_score(data, cluster_labels)
    print("For n_clusters =", n_clusters,
          "The average silhouette_score is :", silhouette_avg)

    # Compute the silhouette scores for each sample
    sample_silhouette_values = silhouette_samples(data, cluster_labels)

    y_lower = 10
    for i in range(n_clusters):
        # Aggregate the silhouette scores for samples belonging to
        # cluster i, and sort them
        ith_cluster_silhouette_values = \
            sample_silhouette_values[cluster_labels == i]

        ith_cluster_silhouette_values.sort()

        size_cluster_i = ith_cluster_silhouette_values.shape[0]
        y_upper = y_lower + size_cluster_i

        color = cm.nipy_spectral(float(i) / n_clusters)
        plt.fill_betweenx(np.arange(y_lower, y_upper),
                          0, ith_cluster_silhouette_values,
                          facecolor=color, edgecolor=color, alpha=0.7)

        # Label the silhouette plots with their cluster numbers at the middle
        plt.text(-0.15, y_lower + 0.5 * size_cluster_i, str(i))
        
        # Compute the new y_lower for next plot
        y_lower = y_upper + 10  # 10 for the 0 samples

    plt.title("The silhouette plot for the various clusters.")
    plt.xlabel("The silhouette coefficient values")
    plt.ylabel("Cluster label")

    # The vertical line for average silhouette score of all the values
    plt.axvline(x=silhouette_avg, color="red", linestyle="--")

    plt.yticks([])  # Clear the yaxis labels / ticks
    plt.xticks([-1, -0.8, -0.6, -0.4, -0.2, 0, 0.2, 0.4, 0.6, 0.8, 1])


    plt.title(("Silhouette analysis for KMeans clustering on Dataset "
                  "with n_clusters = %d" % n_clusters),
                 fontsize=14, fontweight='bold')

  plt.show()
  return

# %%
silhouette('klopp_data_epl_kmeans_lost_points.csv')
# Out:
# For n_clusters = 2 The average silhouette_score is : 0.3952986116103981
# For n_clusters = 3 The average silhouette_score is : 0.32875873532423566
# For n_clusters = 4 The average silhouette_score is : 0.3456859212217401
# For n_clusters = 5 The average silhouette_score is : 0.33243699073622746
# For n_clusters = 6 The average silhouette_score is : 0.33981905248360367
# For n_clusters = 7 The average silhouette_score is : 0.31858661393828636
# For n_clusters = 8 The average silhouette_score is : 0.28902136272297996
# For n_clusters = 9 The average silhouette_score is : 0.29496358629557584
# For n_clusters = 10 The average silhouette_score is : 0.296109404621815

# %%
silhouette('klopp_data_epl_kmeans_gained_points.csv')
# Out:
# For n_clusters = 2 The average silhouette_score is : 0.38517618610582094
# For n_clusters = 3 The average silhouette_score is : 0.322487698069
# For n_clusters = 4 The average silhouette_score is : 0.352529577697058
# For n_clusters = 5 The average silhouette_score is : 0.3776420150605191
# For n_clusters = 6 The average silhouette_score is : 0.3892049685848476
# For n_clusters = 7 The average silhouette_score is : 0.4010781324522414
# For n_clusters = 8 The average silhouette_score is : 0.3919081979617511
# For n_clusters = 9 The average silhouette_score is : 0.33847719610749744
# For n_clusters = 10 The average silhouette_score is : 0.2971111958382051

# %%
silhouette('rodgers_data_epl_kmeans_gained_points.csv')
# Out:
# For n_clusters = 2 The average silhouette_score is : 0.4801376753954058
# For n_clusters = 3 The average silhouette_score is : 0.3154225384757458
# For n_clusters = 4 The average silhouette_score is : 0.2931957567298623
# For n_clusters = 5 The average silhouette_score is : 0.29223575617258835
# For n_clusters = 6 The average silhouette_score is : 0.31075513022957973
# For n_clusters = 7 The average silhouette_score is : 0.2693246417853971
# For n_clusters = 8 The average silhouette_score is : 0.2784981496186555
# For n_clusters = 9 The average silhouette_score is : 0.2759379922032877
# For n_clusters = 10 The average silhouette_score is : 0.2479862383426154

# %%
silhouette('rodgers_data_epl_kmeans_lost_points.csv')
# Out:
# For n_clusters = 2 The average silhouette_score is : 0.5011117982241331
# For n_clusters = 3 The average silhouette_score is : 0.3355016027844755
# For n_clusters = 4 The average silhouette_score is : 0.2784514121536242
# For n_clusters = 5 The average silhouette_score is : 0.28285737557313845
# For n_clusters = 6 The average silhouette_score is : 0.28613152132125563
# For n_clusters = 7 The average silhouette_score is : 0.29541723969713807
# For n_clusters = 8 The average silhouette_score is : 0.2888051821243855
# For n_clusters = 9 The average silhouette_score is : 0.2873671338915187
# For n_clusters = 10 The average silhouette_score is : 0.28261811218813876
